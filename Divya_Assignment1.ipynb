# %%
a=33
b=45
addition = a+b
display(addition)
# Out:
# 78

# %%
name = 'divyasri'
for i in name:
  display(i)
# Out:
# 'd''i''v''y''a''s''r''i'

# %%
name = 'divyasri'
for i in name:
  if i == 'i':
    display("Successfull")
  else:
    display("not successful")
# Out:
# 'not successful''Successfull''not successful''not successful''not successful''not successful''not successful''Successfull'

# %%
name = "divyasri"
count=0
for i in name:
  if i == "i":
    count= count+1
display(count)
# Out:
# 2

# %%
l1=[22,454,43,1,5,12,34,65]
for i in l1:
  if i%2==0:
    display("even")
  else:
    display("odd")
# Out:
# 'even''even''odd''odd''odd''even''even''odd'

# %%
def power(a):
  result=0
  result=a**3
  return result

# %%
display(power(5))
# Out:
# 125

# %%
def minimum(a,b,c):
  if a<b and a<c:
    return a
  elif b<a and b<c:
    return b
  else:
    return c

# %%
display(minimum(22,1,6))
# Out:
# 1

# %%
import pandas as pd
import numpy as np

# %%
from numpy.random import randn

# %%
df = pd.DataFrame(randn(3,3),index=['A','B','C',],columns=['X','Y','Z'])

# %%
display(randn(3,3))
# Out:
# array([[-1.75146521,  0.86113106, -0.22127793],
#        [-0.65653388, -0.26414803,  0.54475198],
#        [-0.98172977, -1.28080984, -1.57711307]])

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>X</th><th>Y</th><th>Z</th></tr></thead><tbody><tr><td>-0.41307877831991585</td><td>1.1657603656542046</td><td>0.0845882131071651</td></tr><tr><td>-0.5964379819617683</td><td>0.37137473592974085</td><td>0.8017998321278612</td></tr><tr><td>-1.4721131726251977</td><td>0.6295832041756217</td><td>1.1393093638648157</td></tr></tbody></table></div>

# %%
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>X</th>
#       <th>Y</th>
#       <th>Z</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A</th>
#       <td>-0.413079</td>
#       <td>1.165760</td>
#       <td>0.084588</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>-0.596438</td>
#       <td>0.371375</td>
#       <td>0.801800</td>
#     </tr>
#     <tr>
#       <th>C</th>
#       <td>-1.472113</td>
#       <td>0.629583</td>
#       <td>1.139309</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
display(df['X'])
# Out:
# A   -0.413079
# B   -0.596438
# C   -1.472113
# Name: X, dtype: float64

# %%
df['W']=df['X']+df['Z']

# %%
display(df['W'])
# Out:
# A   -0.328491
# B    0.205362
# C   -0.332804
# Name: W, dtype: float64

# %%
df['W']
# Out:
# Out[25]: A   -0.328491
# B    0.205362
# C   -0.332804
# Name: W, dtype: float64

# %%
df.loc['A']
# Out:
# Out[26]: X   -0.413079
# Y    1.165760
# Z    0.084588
# W   -0.328491
# Name: A, dtype: float64

# %%
df=df[df>0]

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>X</th><th>Y</th><th>Z</th><th>W</th></tr></thead><tbody><tr><td>null</td><td>1.1657603656542046</td><td>0.0845882131071651</td><td>null</td></tr><tr><td>null</td><td>0.37137473592974085</td><td>0.8017998321278612</td><td>0.20536185016609287</td></tr><tr><td>null</td><td>0.6295832041756217</td><td>1.1393093638648157</td><td>null</td></tr></tbody></table></div>

# %%
df.fillna(2)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>X</th>
#       <th>Y</th>
#       <th>Z</th>
#       <th>W</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A</th>
#       <td>2.0</td>
#       <td>1.165760</td>
#       <td>0.084588</td>
#       <td>2.000000</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>2.0</td>
#       <td>0.371375</td>
#       <td>0.801800</td>
#       <td>0.205362</td>
#     </tr>
#     <tr>
#       <th>C</th>
#       <td>2.0</td>
#       <td>0.629583</td>
#       <td>1.139309</td>
#       <td>2.000000</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
import pandas as pd
# Create dataframe
data = {'products':['Iphone','oneplus','nokia','samsung','Motorola'],
       'country':['Apple','china','India','Korea','Japan'],
       'sales':[200,120,340,124,243]}

# %%
df = pd.DataFrame(data)

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>products</th><th>country</th><th>sales</th></tr></thead><tbody><tr><td>Iphone</td><td>Apple</td><td>200</td></tr><tr><td>oneplus</td><td>china</td><td>120</td></tr><tr><td>nokia</td><td>India</td><td>340</td></tr><tr><td>samsung</td><td>Korea</td><td>124</td></tr><tr><td>Motorola</td><td>Japan</td><td>243</td></tr></tbody></table></div>

# %%
bycountry=df.groupby('country')

# %%
bycountry.describe()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead tr th {
#         text-align: left;
#     }
#
#     .dataframe thead tr:last-of-type th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th colspan="8" halign="left">sales</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>count</th>
#       <th>mean</th>
#       <th>std</th>
#       <th>min</th>
#       <th>25%</th>
#       <th>50%</th>
#       <th>75%</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>country</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Apple</th>
#       <td>1.0</td>
#       <td>200.0</td>
# ...

# %%
by_country = df.groupby("country")

# %%
by_country.mean()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sales</th>
#     </tr>
#     <tr>
#       <th>country</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Apple</th>
#       <td>200</td>
#     </tr>
#     <tr>
#       <th>India</th>
#       <td>340</td>
#     </tr>
#     <tr>
#       <th>Japan</th>
#       <td>243</td>
#     </tr>
#     <tr>
#       <th>Korea</th>
#       <td>124</td>
#     </tr>
#     <tr>
#       <th>china</th>
#       <td>120</td>
#     </tr>
#   </tbody>
# </table>
# </div>
